# %% [markdown]
# # This notebook is for processing images fully in MegaDetector. This is for when you want the images to be annotated and not just the json file to be used in timelapse.

# %% [markdown]
# # If you are unsure what to do here then please go back to First_time_setup so that you can learn what is going on

# %%
import os

# %%
folder_path = os.path.abspath("C:/Users/Public/WLF_Cam_Data/20April2026/SOU4_20April2026/DCIM")

# %%
# old one! do not uncomment Bernie new one below!!python "C:/Users/Public/Documents/MegaDetector_App/MegaDetector/megadetector/detection/run_detector_batch.py" MDV5A "{folder_path}" "C:/Users/Public/WLF_Cam_Data/20April2026/SOU4_20April2026/DCIM/SOU4_20April2026.json" --output_relative_filenames --recursive --checkpoint_frequency 1000 --quiet
# Out:
# ...
# Traceback (most recent call last):
#   File "C:\Users\Public\Documents\cameratraps-detector\lib\urllib\request.py", line 1354, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#   File "C:\Users\Public\Documents\cameratraps-detector\lib\http\client.py", line 1256, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\Users\Public\Documents\cameratraps-detector\lib\http\client.py", line 1302, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\Users\Public\Documents\cameratraps-detector\lib\http\client.py", line 1251, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\Users\Public\Documents\cameratraps-detector\lib\http\client.py", line 1011, in _send_output
#     self.send(msg)
#   File "C:\Users\Public\Documents\cameratraps-detector\lib\http\client.py", line 951, in send
#     self.connect()
# ...

# %% [markdown]
# Note- running batch py file below we changed the model path and hardcoded it in, it was downloading the model file from each person's temp file and getting ssl error as a result

# %%
# !python "C:/Users/Public/Documents/MegaDetector_App/MegaDetector/megadetector/detection/run_detector_batch.py"  "C:\Users\Public\Documents\MegaDetector_App\Models\md_v5a.0.1.pt" "{folder_path}" "C:/Users/Public/WLF_Cam_Data/20April2026/SOU4_20April2026/DCIM/SOU4_20April2026.json" --output_relative_filenames --recursive --checkpoint_frequency 1000 --quiet
# Out:
# 4977 image files found in the input directory
# The checkpoint file will be written to C:/Users/Public/WLF_Cam_Data/20April2026/SOU4_20April2026/DCIM\md_checkpoint_20260608210617.json
# PyTorch reports 1 available CUDA devices
# GPU available: True
# Imported YOLOv5 as utils.*
# Using PyTorch version 2.2.2
# Sending model to GPU
# Loaded model in 4.46 seconds
# Loaded model in 4.46 seconds
# Writing a new checkpoint after having processed 1000 images since last restart
# Writing a new checkpoint after having processed 2000 images since last restart
# Writing a new checkpoint after having processed 3000 images since last restart
# Writing a new checkpoint after having processed 4000 images since last restart
# Finished inference for 4977 images in 3 minutes and 37.01 seconds (22.93 images per second)
# ...
# Output file saved at C:/Users/Public/WLF_Cam_Data/20April2026/SOU4_20April2026/DCIM/SOU4_20April2026.json
# ...

# %%
#"C:\Users\Public\Documents\MegaDetector_App\Models\md_v5a.0.0.pt"

# %%
json_path = os.path.abspath("C:/Users/Public/WLF_Cam_Data/BGP/14Jan2026/BGP2_14Jan2026/DCIM/BGP2_14Jan2026.json")

# %%
output_path = os.path.abspath('C:/Users/Public/WLF_Cam_Data/BGP/14Jan2026/BGP2_14Jan2026/DCIM/detections')

# %%
# !python "C:/Users/Public/Documents/MegaDetector_App/MegaDetector/megadetector/postprocessing/postprocess_batch_results.py" "{json_path}" "{output_path}" --image_base_dir "{folder_path}" --num_images_to_sample -1

# %%
# %pip install --upgrade pip certifi pip-system-certs
