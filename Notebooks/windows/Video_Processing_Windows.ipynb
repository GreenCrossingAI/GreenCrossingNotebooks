# %% [markdown]
# # Video Processing Notebook for MegaDetector
#
# This notebook extracts frames from video files and processes them through MegaDetector for wildlife detection.
#
# **System Requirements:**
# - Windows OS
# - Python 3.8+
# - MegaDetector installed
# - OpenCV

# %%
import certifi
print(certifi.where())
# Out:
# C:\Users\Public\Documents\cameratraps-detector\lib\site-packages\certifi\cacert.pem

# %%
import urllib.request
urllib.request.urlretrieve("https://github.com", "test.html")
print("success")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File C:\Users\Public\Documents\cameratraps-detector\lib\urllib\request.py:1354, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1353 try:
# -> 1354     h.request(req.get_method(), req.selector, req.data, headers,
#    1355               encode_chunked=req.has_header('Transfer-encoding'))
#    1356 except OSError as err: # timeout error
#
# File C:\Users\Public\Documents\cameratraps-detector\lib\http\client.py:1256, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1255 """Send a complete request to the server."""
# -> 1256 self._send_request(method, url, body, headers, encode_chunked)
#
# File C:\Users\Public\Documents\cameratraps-detector\lib\http\client.py:1302, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1301     body = _encode(body, 'body')
# -> 1302 self.endheaders(body, encode_chunked=encode_chunked)
#
# File C:\Users\Public\Documents\cameratraps-detector\lib\http\client.py:1251, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1250     raise CannotSendHeader()
# -> 1251 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File C:\Users\Public\Documents\cameratraps-detector\lib\http\client.py:1011, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1010 del self._buffer[:]
# -> 1011 self.send(msg)
#    1013 if message_body is not None:
#    1014
#    1015     # create a consistent interface to message_body
#
# File C:\Users\Public\Documents\cameratraps-detector\lib\http\client.py:951, in HTTPConnection.send(self, data)
#     950 if self.auto_open:
# --> 951     self.connect()
#     952 else:
#
# File C:\Users\Public\Documents\cameratraps-detector\lib\http\client.py:1425, in HTTPSConnection.connect(self)
#    1423     server_hostname = self.host
# -> 1425 self.sock = self._context.wrap_socket(self.sock,
#    1426                                       server_hostname=server_hostname)
#
# File C:\Users\Public\Documents\cameratraps-detector\lib\ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File C:\Users\Public\Documents\cameratraps-detector\lib\ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#
# File C:\Users\Public\Documents\cameratraps-detector\lib\ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1131)
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[9], line 2
#       1 import urllib.request
# ----> 2 urllib.request.urlretrieve("https://github.com", "test.html")
#       3 print("success")
#
# File C:\Users\Public\Documents\cameratraps-detector\lib\urllib\request.py:247, in urlretrieve(url, filename, reporthook, data)
#     230 """
#     231 Retrieve a URL into a temporary location on disk.
#     232
#    (...)
#     243 data file as well as the resulting HTTPMessage object.
#     244 """
#     245 url_type, path = _splittype(url)
# --> 247 with contextlib.closing(urlopen(url, data)) as fp:
#     248     headers = fp.info()
#     250     # Just return the local path and the "headers" for file://
#     251     # URLs. No sense in performing a copy unless requested.
#
# File C:\Users\Public\Documents\cameratraps-detector\lib\urllib\request.py:222, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220 else:
#     221     opener = _opener
# --> 222 return opener.open(url, data, timeout)
#
# File C:\Users\Public\Documents\cameratraps-detector\lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     522     req = meth(req)
#     524 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525 response = self._open(req, data)
#     527 # post-process response
#     528 meth_name = protocol+"_response"
#
# File C:\Users\Public\Documents\cameratraps-detector\lib\urllib\request.py:542, in OpenerDirector._open(self, req, data)
#     539     return result
#     541 protocol = req.type
# --> 542 result = self._call_chain(self.handle_open, protocol, protocol +
#     543                           '_open', req)
#     544 if result:
#     545     return result
#
# File C:\Users\Public\Documents\cameratraps-detector\lib\urllib\request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     500 for handler in handlers:
#     501     func = getattr(handler, meth_name)
# --> 502     result = func(*args)
#     503     if result is not None:
#     504         return result
#
# File C:\Users\Public\Documents\cameratraps-detector\lib\urllib\request.py:1397, in HTTPSHandler.https_open(self, req)
#    1396 def https_open(self, req):
# -> 1397     return self.do_open(http.client.HTTPSConnection, req,
#    1398         context=self._context, check_hostname=self._check_hostname)
#
# File C:\Users\Public\Documents\cameratraps-detector\lib\urllib\request.py:1357, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1354         h.request(req.get_method(), req.selector, req.data, headers,
#    1355                   encode_chunked=req.has_header('Transfer-encoding'))
#    1356     except OSError as err: # timeout error
# -> 1357         raise URLError(err)
#    1358     r = h.getresponse()
#    1359 except:
#
# URLError: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1131)>

# %%
pip install --upgrade certifi
# Out:
# Requirement already satisfied: certifi in c:\users\public\documents\cameratraps-detector\lib\site-packages (2026.5.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade cameratraps-detector
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement cameratraps-detector (from versions: none)
# ERROR: No matching distribution found for cameratraps-detector

# %%
# Install required package if needed
# !pip install opencv-python-headless
# Out:
# Requirement already satisfied: opencv-python-headless in c:\users\public\documents\cameratraps-detector\lib\site-packages (4.10.0.82)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\public\documents\cameratraps-detector\lib\site-packages (from opencv-python-headless) (1.23.5)

# %%
import os
import json
import shutil
import subprocess
import time
from pathlib import Path
import cv2
import tkinter as tk
from tkinter import filedialog as fd
#Megadetector imports
from megadetector.utils import path_utils
from megadetector.detection import video_utils
from megadetector.utils.ct_utils import write_json
from megadetector.visualization import visualization_utils as vis_utils
from megadetector.detection.video_utils import frame_results_to_video_results, FrameToVideoOptions

# Add the directory containing video_utils.py to the system path
import sys
sys.path.append("C:/Users/Public/Documents/MegaDetector_App/MegaDetector/megadetector/detection")

# Create a hidden root window for file dialogs
root = tk.Tk()
root.withdraw()
root.attributes('-topmost', True)

print("✅ All imports successful!")
# Out:
# ✅ All imports successful!

# %% [markdown]
# ## Configuration
#
# Set up paths and detection parameters.

# %%
# MegaDetector installation path
MEGADETECTOR_ROOT = Path("C:/Users/Public/Documents/MegaDetector_App/MegaDetector")

# Model configuration
MODEL_NAME = "MDV5A"

# Detection parameters
ANIMAL_CATEGORY_ID = 1
CONF_THRESH = 0.2  # Confidence threshold (0.0 to 1.0)

# Verify MegaDetector is installed
assert (MEGADETECTOR_ROOT / "megadetector/detection/run_detector_batch.py").exists(), \
    f"MegaDetector not found at {MEGADETECTOR_ROOT}"

print(f"✅ MegaDetector found at: {MEGADETECTOR_ROOT}")
print(f"Model: {MODEL_NAME}")
print(f"Confidence threshold: {CONF_THRESH}")
# Out:
# ✅ MegaDetector found at: C:\Users\Public\Documents\MegaDetector_App\MegaDetector
# Model: MDV5A
# Confidence threshold: 0.2

# %% [markdown]
# ## Select Directories
#
# Choose your input folder (containing videos) and output folder (where results will be saved).

# %%
# Select input folder containing video files
input_folder = fd.askdirectory(title="Select folder containing video files")
if not input_folder:
    raise ValueError("No input folder selected")

DATA_DIR = Path(input_folder)
print("Input folder:", DATA_DIR)
# Out:
# Input folder: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\in_04_100

# %%
# Select output folder for all results
output_folder = fd.askdirectory(title="Select folder for output (detections, videos, etc.)")
if not output_folder:
    raise ValueError("No output folder selected")

OUTPUT_DIR = Path(output_folder)
OUTPUT_DIR.mkdir(exist_ok=True)
print("Output folder:", OUTPUT_DIR)
# Out:
# Output folder: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04

# %% [markdown]
# ## Helper Functions

# %%
def find_all_videos(root):
    """Find all video files recursively."""
    exts = (".mp4", ".mov", ".avi", ".MP4", ".MOV", ".AVI")
    videos = []
    for r, _, files in os.walk(root):
        for f in files:
            if f.endswith(exts):
                videos.append(Path(r) / f)
    return sorted(videos)

all_videos = find_all_videos(DATA_DIR)
print(f"Found {len(all_videos)} videos")

# Show first 20 videos
for v in all_videos[:20]:
    print(f"  {v.name}")
    
if len(all_videos) > 20:
    print(f"  ... and {len(all_videos) - 20} more")
# Out:
# Found 705 videos
#   IMG_0295.MP4
#   IMG_0296.MP4
#   IMG_0297.MP4
#   IMG_0298.MP4
#   IMG_0299.MP4
#   IMG_0300.MP4
#   IMG_0301.MP4
#   IMG_0302.MP4
#   IMG_0303.MP4
#   IMG_0304.MP4
#   IMG_0305.MP4
#   IMG_0306.MP4
#   IMG_0307.MP4
#   IMG_0308.MP4
#   IMG_0309.MP4
#   IMG_0310.MP4
#   IMG_0311.MP4
#   IMG_0312.MP4
#   IMG_0313.MP4
#   IMG_0314.MP4
#   ... and 685 more

# %%
def resolve_frame_path(frames_dir, file_field):
    """Resolve the path to a frame file from MegaDetector JSON."""
    p = Path(file_field)
    if p.is_absolute() or p.exists():
        return p
    return frames_dir / p.name

# %%
def video_has_any_animal(images, conf_thresh=0.0):
    """Check if any frame in the video has animal detections above threshold."""
    for img in images:
        for det in img.get("detections", []):
            if int(det["category"]) == ANIMAL_CATEGORY_ID and det["conf"] >= conf_thresh:
                return True
    return False

# %% [markdown]
# ## Process Videos
#
# This cell processes each video individually:
# 1. Extract frames
# 2. Run MegaDetector
# 3. Draw bounding boxes on frames with detections
# 4. Create output video (only for videos WITH animal detections)
# 5. Clean up temporary frames
#
# **Note:** You can test with a few videos first by uncommenting the test line in the loop.

# %%
batch_start = time.perf_counter()

videos_processed = 0
videos_with_animals = 0
videos_skipped = 0
videos_with_animals_list = []
videos_skipped_list = []

for video_path in all_videos:
# for video_path in all_videos[:3]:  # TESTING: Uncomment to process only first 3 videos

    print("\n" + "="*50)
    print("Processing:", video_path.name)
    print("="*50)

    # ----------------------------------------
    # Per-video output paths
    # ----------------------------------------
    video_stem = video_path.stem
    video_out_dir = OUTPUT_DIR / video_stem

    frames_dir = video_out_dir / "frames"
    json_path = video_out_dir / "detections.json"
    out_video = video_out_dir / f"{video_stem}_detected.mp4"

    video_out_dir.mkdir(parents=True, exist_ok=True)

    print("Frames:", frames_dir)
    print("JSON:", json_path)
    print("Output:", out_video)

    # ----------------------------------------
    # Clean frames dir
    # ----------------------------------------
    if frames_dir.exists():
        shutil.rmtree(frames_dir)
    frames_dir.mkdir()

    # ----------------------------------------
    # Extract frames
    # ----------------------------------------
    print("\n[1/4] Extracting frames...")
    cap = cv2.VideoCapture(str(video_path))
    fps = cap.get(cv2.CAP_PROP_FPS)

    frame_idx = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        cv2.imwrite(
            str(frames_dir / f"frame_{frame_idx:05d}.jpg"),
            frame
        )
        frame_idx += 1

    cap.release()
    print(f"  ✓ Extracted {frame_idx} frames @ {fps:.2f} FPS")

    if frame_idx == 0:
        print("  ✗ No frames extracted, skipping video")
        continue

    # ----------------------------------------
    # Run MegaDetector
    # ----------------------------------------
    print("\n[2/4] Running MegaDetector...")
    cmd = [
        "python",
        str(MEGADETECTOR_ROOT / "megadetector/detection/run_detector_batch.py"),
        MODEL_NAME,
        str(frames_dir),
        str(json_path),
    ]

    subprocess.run(cmd, check=True)
    print("  ✓ Detection complete")

    # ----------------------------------------
    # Load detections
    # ----------------------------------------
    with open(json_path) as f:
        md = json.load(f)

    images = md.get("images", [])
    print(f"  ✓ Loaded {len(images)} detection results")

    if len(images) != frame_idx:
        print(f"  ✗ Frame/JSON mismatch ({frame_idx} frames vs {len(images)} results), skipping")
        shutil.rmtree(frames_dir)
        continue

    # ----------------------------------------
    # Check for animal detections
    # ----------------------------------------
    print("\n[3/4] Checking for animal detections...")
    if not video_has_any_animal(images, CONF_THRESH):
        print(f"  ✗ No animal detections (conf >= {CONF_THRESH}) — skipping output video")
        shutil.rmtree(frames_dir)
        videos_skipped += 1
        videos_processed += 1
        videos_skipped_list.append(video_path.name)
        continue

    print(f"  ✓ Animals detected!")

    # ----------------------------------------
    # Initialize output video
    # ----------------------------------------
    print("\n[4/4] Creating output video with bounding boxes...")
    first_frame_path = resolve_frame_path(frames_dir, images[0]["file"])
    first_frame = cv2.imread(str(first_frame_path))

    if first_frame is None:
        print("  ✗ Cannot read first frame, skipping")
        continue

    h, w, _ = first_frame.shape

    out = cv2.VideoWriter(
        str(out_video),
        cv2.VideoWriter_fourcc(*"mp4v"),
        fps,
        (w, h),
    )

    # ----------------------------------------
    # Write video with bounding boxes
    # ----------------------------------------
    written = 0
    detections_drawn = 0

    for img in images:
        frame_path = resolve_frame_path(frames_dir, img["file"])
        frame = cv2.imread(str(frame_path))
        if frame is None:
            continue

        # Draw bounding boxes for animal detections
        for det in img.get("detections", []):
            if int(det["category"]) != ANIMAL_CATEGORY_ID:
                continue
            if det["conf"] < CONF_THRESH:
                continue

            x, y, bw, bh = det["bbox"]
            x1 = int(x * w)
            y1 = int(y * h)
            x2 = int((x + bw) * w)
            y2 = int((y + bh) * h)

            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(
                frame,
                f"{det['conf']:.2f}",
                (x1, max(y1 - 5, 10)),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.5,
                (0, 255, 0),
                1,
            )
            detections_drawn += 1

        out.write(frame)
        written += 1

    out.release()
    print(f"  ✓ Wrote {written} frames with {detections_drawn} bounding boxes")
    print(f"  ✓ Output video: {out_video}")
    
    videos_with_animals += 1
    videos_processed += 1
    videos_with_animals_list.append(video_path.name)
    
    # ----------------------------------------
    # Cleanup frames
    # ----------------------------------------
    shutil.rmtree(frames_dir)
    print("  ✓ Cleaned up temporary frames")

print("\n" + "="*50)
print("PROCESSING COMPLETE")
print("="*50)
# Out:
# ==================================================
# Processing: IMG_0295.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0295\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0295\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0295\IMG_0295_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0296.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0296\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0296\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0296\IMG_0296_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0297.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0297\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0297\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0297\IMG_0297_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0298.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0298\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0298\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0298\IMG_0298_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0299.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0299\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0299\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0299\IMG_0299_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0300.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0300\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0300\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0300\IMG_0300_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0301.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0301\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0301\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0301\IMG_0301_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0302.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0302\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0302\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0302\IMG_0302_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0303.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0303\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0303\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0303\IMG_0303_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0304.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0304\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0304\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0304\IMG_0304_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0305.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0305\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0305\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0305\IMG_0305_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0306.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0306\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0306\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0306\IMG_0306_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0307.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0307\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0307\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0307\IMG_0307_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0308.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0308\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0308\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0308\IMG_0308_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0309.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0309\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0309\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0309\IMG_0309_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0310.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0310\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0310\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0310\IMG_0310_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0311.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0311\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0311\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0311\IMG_0311_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0312.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0312\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0312\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0312\IMG_0312_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0313.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0313\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0313\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0313\IMG_0313_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0314.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0314\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0314\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0314\IMG_0314_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0315.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0315\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0315\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0315\IMG_0315_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0316.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0316\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0316\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0316\IMG_0316_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0317.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0317\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0317\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0317\IMG_0317_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0318.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0318\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0318\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0318\IMG_0318_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0319.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0319\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0319\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0319\IMG_0319_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✓ Animals detected!
#
# [4/4] Creating output video with bounding boxes...
#   ✓ Wrote 315 frames with 1 bounding boxes
#   ✓ Output video: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0319\IMG_0319_detected.mp4
#   ✓ Cleaned up temporary frames
#
# ==================================================
# Processing: IMG_0320.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0320\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0320\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0320\IMG_0320_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0321.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0321\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0321\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0321\IMG_0321_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0322.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0322\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0322\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0322\IMG_0322_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0323.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0323\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0323\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0323\IMG_0323_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0324.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0324\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0324\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0324\IMG_0324_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0325.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0325\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0325\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0325\IMG_0325_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0326.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0326\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0326\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0326\IMG_0326_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0327.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0327\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0327\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0327\IMG_0327_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0328.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0328\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0328\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0328\IMG_0328_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0329.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0329\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0329\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0329\IMG_0329_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0330.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0330\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0330\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0330\IMG_0330_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0331.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0331\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0331\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0331\IMG_0331_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0332.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0332\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0332\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0332\IMG_0332_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0333.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0333\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0333\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0333\IMG_0333_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0334.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0334\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0334\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0334\IMG_0334_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0335.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0335\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0335\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0335\IMG_0335_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0336.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0336\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0336\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0336\IMG_0336_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✓ Animals detected!
#
# [4/4] Creating output video with bounding boxes...
#   ✓ Wrote 315 frames with 2 bounding boxes
#   ✓ Output video: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0336\IMG_0336_detected.mp4
#   ✓ Cleaned up temporary frames
#
# ==================================================
# Processing: IMG_0337.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0337\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0337\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0337\IMG_0337_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✓ Animals detected!
#
# [4/4] Creating output video with bounding boxes...
#   ✓ Wrote 315 frames with 12 bounding boxes
#   ✓ Output video: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0337\IMG_0337_detected.mp4
#   ✓ Cleaned up temporary frames
#
# ==================================================
# Processing: IMG_0338.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0338\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0338\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0338\IMG_0338_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0339.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0339\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0339\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0339\IMG_0339_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0340.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0340\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0340\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0340\IMG_0340_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0341.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0341\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0341\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0341\IMG_0341_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0342.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0342\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0342\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0342\IMG_0342_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0343.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0343\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0343\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0343\IMG_0343_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0344.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0344\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0344\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0344\IMG_0344_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0345.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0345\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0345\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0345\IMG_0345_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0346.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0346\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0346\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0346\IMG_0346_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0347.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0347\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0347\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0347\IMG_0347_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0348.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0348\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0348\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0348\IMG_0348_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0349.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0349\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0349\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0349\IMG_0349_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0350.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0350\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0350\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0350\IMG_0350_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0351.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0351\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0351\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0351\IMG_0351_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0352.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0352\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0352\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0352\IMG_0352_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0353.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0353\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0353\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0353\IMG_0353_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0354.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0354\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0354\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0354\IMG_0354_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0355.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0355\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0355\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0355\IMG_0355_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0356.MP4
# ==================================================
# ...
#   ✓ Animals detected!
#
# [4/4] Creating output video with bounding boxes...
#   ✓ Wrote 315 frames with 3 bounding boxes
#   ✓ Output video: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0411\IMG_0411_detected.mp4
#   ✓ Cleaned up temporary frames
#
# ==================================================
# Processing: IMG_0412.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0412\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0412\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0412\IMG_0412_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✓ Animals detected!
#
# [4/4] Creating output video with bounding boxes...
#   ✓ Wrote 315 frames with 2 bounding boxes
#   ✓ Output video: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0412\IMG_0412_detected.mp4
#   ✓ Cleaned up temporary frames
#
# ==================================================
# Processing: IMG_0413.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0413\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0413\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0413\IMG_0413_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✓ Animals detected!
#
# [4/4] Creating output video with bounding boxes...
#   ✓ Wrote 315 frames with 2 bounding boxes
#   ✓ Output video: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0413\IMG_0413_detected.mp4
#   ✓ Cleaned up temporary frames
#
# ==================================================
# Processing: IMG_0414.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0414\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0414\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0414\IMG_0414_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0415.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0415\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0415\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0415\IMG_0415_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0416.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0416\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0416\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0416\IMG_0416_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0417.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0417\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0417\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0417\IMG_0417_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0418.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0418\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0418\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0418\IMG_0418_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0419.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0419\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0419\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0419\IMG_0419_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0420.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0420\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0420\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0420\IMG_0420_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0421.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0421\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0421\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0421\IMG_0421_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0422.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0422\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0422\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0422\IMG_0422_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0423.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0423\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0423\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0423\IMG_0423_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0424.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0424\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0424\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0424\IMG_0424_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0425.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0425\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0425\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0425\IMG_0425_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0426.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0426\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0426\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0426\IMG_0426_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0427.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0427\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0427\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0427\IMG_0427_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0428.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0428\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0428\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0428\IMG_0428_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
#   ✓ Detection complete
#   ✓ Loaded 315 detection results
#
# [3/4] Checking for animal detections...
#   ✗ No animal detections (conf >= 0.2) — skipping output video
#
# ==================================================
# Processing: IMG_0429.MP4
# ==================================================
# Frames: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0429\frames
# JSON: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0429\detections.json
# Output: C:\Users\Public\WLF_Cam_Data\MtA_Exit_Project\18March2026\MtA_NW1_18March2026\DCIM\outputs\out_04\IMG_0429\IMG_0429_detected.mp4
#
# [1/4] Extracting frames...
#   ✓ Extracted 315 frames @ 30.00 FPS
#
# [2/4] Running MegaDetector...
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[9], line 76
#      67 print("\n[2/4] Running MegaDetector...")
#      68 cmd = [
#      69     "python",
#      70     str(MEGADETECTOR_ROOT / "megadetector/detection/run_detector_batch.py"),
#    (...)
#      73     str(json_path),
#      74 ]
# ---> 76 subprocess.run(cmd, check=True)
#      77 print("  ✓ Detection complete")
#      79 # ----------------------------------------
#      80 # Load detections
#      81 # ----------------------------------------
#
# File C:\Users\Public\Documents\cameratraps-detector\lib\subprocess.py:516, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     514     retcode = process.poll()
#     515     if check and retcode:
# --> 516         raise CalledProcessError(retcode, process.args,
#     517                                  output=stdout, stderr=stderr)
#     518 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['python', 'C:\\Users\\Public\\Documents\\MegaDetector_App\\MegaDetector\\megadetector\\detection\\run_detector_batch.py', 'MDV5A', 'C:\\Users\\Public\\WLF_Cam_Data\\MtA_Exit_Project\\18March2026\\MtA_NW1_18March2026\\DCIM\\outputs\\out_04\\IMG_0429\\frames', 'C:\\Users\\Public\\WLF_Cam_Data\\MtA_Exit_Project\\18March2026\\MtA_NW1_18March2026\\DCIM\\outputs\\out_04\\IMG_0429\\detections.json']' returned non-zero exit status 3221226505.

# %% [markdown]
# ## Processing Summary

# %%
batch_end = time.perf_counter()
elapsed = batch_end - batch_start

print("\n" + "="*50)
print("BATCH PROCESSING SUMMARY")
print("="*50)
print(f"Total videos found     : {len(all_videos)}")
print(f"Videos processed       : {videos_processed}")
print(f"Videos with animals    : {videos_with_animals}")
print(f"Videos skipped (empty) : {videos_skipped}")
print(f"Total elapsed time     : {elapsed:.2f} seconds ({elapsed/60:.1f} minutes)")
print(f"Average per video      : {elapsed / max(videos_processed, 1):.2f} seconds")

print("\n" + "-"*50)
print("Videos WITH animal detections:")
print("-"*50)
if videos_with_animals_list:
    for v in videos_with_animals_list:
        print(f"  ✓ {v}")
else:
    print("  (none)")

print("\n" + "-"*50)
print("Videos with NO animal detections:")
print("-"*50)
if videos_skipped_list:
    for v in videos_skipped_list:
        print(f"  ✗ {v}")
else:
    print("  (none)")

print("\n" + "="*50)
print(f"Output directory: {OUTPUT_DIR}")
print("="*50)
